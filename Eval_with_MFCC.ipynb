# %%
# !sudo apt install -y fluidsynth
# !pip install --upgrade pyfluidsynth
# !pip install pretty_midi
# !pip install midi2audio
# !pip install pydub
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fluid-soundfont-gm libevdev2 libfluidsynth3 libgudev-1.0-0 libinput-bin
#   libinput10 libinstpatch-1.0-2 libmd4c0 libmtdev1 libqt5core5a libqt5dbus5
#   libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libwacom-bin
#   libwacom-common libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxkbcommon-x11-0 qsynth qt5-gtk-platformtheme qttranslations5-l10n
#   timgm6mb-soundfont
# Suggested packages:
#   fluid-soundfont-gs qt5-image-formats-plugins qtwayland5 jackd
# The following NEW packages will be installed:
#   fluid-soundfont-gm fluidsynth libevdev2 libfluidsynth3 libgudev-1.0-0
#   libinput-bin libinput10 libinstpatch-1.0-2 libmd4c0 libmtdev1 libqt5core5a
#   libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5 libwacom-bin
#   libwacom-common libwacom9 libxcb-icccm4 libxcb-image0 libxcb-keysyms1
#   libxcb-render-util0 libxcb-util1 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxkbcommon-x11-0 qsynth qt5-gtk-platformtheme qttranslations5-l10n
#   timgm6mb-soundfont
# 0 upgraded, 32 newly installed, 0 to remove and 45 not upgraded.
# Need to get 148 MB of archives.
# After this operation, 207 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fluid-soundfont-gm all 3.1-5.3 [130 MB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fluidsynth amd64 2.2.5-1 [27.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-bin amd64 2.2.0-1 [13.6 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qsynth amd64 0.9.6-1 [305 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 qt5-gtk-platformtheme amd64 5.15.3+dfsg-2ubuntu0.2 [130 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 qttranslations5-l10n all 5.15.3-1 [1,983 kB]
# Fetched 148 MB in 15s (9,543 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 32.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libqt5core5a:amd64.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../00-libqt5core5a_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libevdev2:amd64.
# Preparing to unpack .../01-libevdev2_1.12.1+dfsg-1_amd64.deb ...
# Unpacking libevdev2:amd64 (1.12.1+dfsg-1) ...
# Selecting previously unselected package libmtdev1:amd64.
# Preparing to unpack .../02-libmtdev1_1.1.6-1build4_amd64.deb ...
# Unpacking libmtdev1:amd64 (1.1.6-1build4) ...
# Selecting previously unselected package libgudev-1.0-0:amd64.
# Preparing to unpack .../03-libgudev-1.0-0_1%3a237-2build1_amd64.deb ...
# Unpacking libgudev-1.0-0:amd64 (1:237-2build1) ...
# Selecting previously unselected package libwacom-common.
# Preparing to unpack .../04-libwacom-common_2.2.0-1_all.deb ...
# Unpacking libwacom-common (2.2.0-1) ...
# Selecting previously unselected package libwacom9:amd64.
# Preparing to unpack .../05-libwacom9_2.2.0-1_amd64.deb ...
# Unpacking libwacom9:amd64 (2.2.0-1) ...
# Selecting previously unselected package libinput-bin.
# Preparing to unpack .../06-libinput-bin_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput-bin (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libinput10:amd64.
# Preparing to unpack .../07-libinput10_1.20.0-1ubuntu0.3_amd64.deb ...
# Unpacking libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Selecting previously unselected package libmd4c0:amd64.
# Preparing to unpack .../08-libmd4c0_0.4.8-1_amd64.deb ...
# Unpacking libmd4c0:amd64 (0.4.8-1) ...
# Selecting previously unselected package libqt5dbus5:amd64.
# Preparing to unpack .../09-libqt5dbus5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5network5:amd64.
# Preparing to unpack .../10-libqt5network5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../11-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../12-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../13-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../14-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../15-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../16-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../17-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../18-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../19-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libqt5gui5:amd64.
# Preparing to unpack .../20-libqt5gui5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5widgets5:amd64.
# Preparing to unpack .../21-libqt5widgets5_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package libqt5svg5:amd64.
# Preparing to unpack .../22-libqt5svg5_5.15.3-1_amd64.deb ...
# Unpacking libqt5svg5:amd64 (5.15.3-1) ...
# Selecting previously unselected package fluid-soundfont-gm.
# Preparing to unpack .../23-fluid-soundfont-gm_3.1-5.3_all.deb ...
# Unpacking fluid-soundfont-gm (3.1-5.3) ...
# Selecting previously unselected package libinstpatch-1.0-2:amd64.
# Preparing to unpack .../24-libinstpatch-1.0-2_1.1.6-1_amd64.deb ...
# Unpacking libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Selecting previously unselected package timgm6mb-soundfont.
# Preparing to unpack .../25-timgm6mb-soundfont_1.3-5_all.deb ...
# Unpacking timgm6mb-soundfont (1.3-5) ...
# Selecting previously unselected package libfluidsynth3:amd64.
# Preparing to unpack .../26-libfluidsynth3_2.2.5-1_amd64.deb ...
# Unpacking libfluidsynth3:amd64 (2.2.5-1) ...
# Selecting previously unselected package fluidsynth.
# Preparing to unpack .../27-fluidsynth_2.2.5-1_amd64.deb ...
# Unpacking fluidsynth (2.2.5-1) ...
# Selecting previously unselected package libwacom-bin.
# Preparing to unpack .../28-libwacom-bin_2.2.0-1_amd64.deb ...
# Unpacking libwacom-bin (2.2.0-1) ...
# Selecting previously unselected package qsynth.
# Preparing to unpack .../29-qsynth_0.9.6-1_amd64.deb ...
# Unpacking qsynth (0.9.6-1) ...
# Selecting previously unselected package qt5-gtk-platformtheme:amd64.
# Preparing to unpack .../30-qt5-gtk-platformtheme_5.15.3+dfsg-2ubuntu0.2_amd64.deb ...
# Unpacking qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Selecting previously unselected package qttranslations5-l10n.
# Preparing to unpack .../31-qttranslations5-l10n_5.15.3-1_all.deb ...
# Unpacking qttranslations5-l10n (5.15.3-1) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up qttranslations5-l10n (5.15.3-1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up fluid-soundfont-gm (3.1-5.3) ...
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/FluidR3_GM.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up timgm6mb-soundfont (1.3-5) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up fluidsynth (2.2.5-1) ...
# Created symlink /etc/systemd/user/default.target.wants/fluidsynth.service → /usr/lib/systemd/user/fluidsynth.service.
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Setting up qsynth (0.9.6-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pyfluidsynth
#   Downloading pyFluidSynth-1.3.3.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pyfluidsynth) (1.25.2)
# Building wheels for collected packages: pyfluidsynth
#   Building wheel for pyfluidsynth (setup.py) ... done
#   Created wheel for pyfluidsynth: filename=pyFluidSynth-1.3.3-py3-none-any.whl size=19185 sha256=201e96243b9c33dd47ba9a97ad5fe014fe707b03a174fdd73582739f45e96ddc
#   Stored in directory: /root/.cache/pip/wheels/e6/9c/2b/b4b194cbb100d6f20136a22b2f76cd329b1a21139ed26c9775
# Successfully built pyfluidsynth
# Installing collected packages: pyfluidsynth
# Successfully installed pyfluidsynth-1.3.3
# Collecting pretty_midi
#   Downloading pretty_midi-0.2.10.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 16.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.25.2)
# Collecting mido>=1.1.16 (from pretty_midi)
#   Downloading mido-1.3.2-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from pretty_midi) (1.16.0)
# Collecting packaging~=23.1 (from mido>=1.1.16->pretty_midi)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 7.0 MB/s eta 0:00:00
# Building wheels for collected packages: pretty_midi
#   Building wheel for pretty_midi (setup.py) ... done
#   Created wheel for pretty_midi: filename=pretty_midi-0.2.10-py3-none-any.whl size=5592289 sha256=5db87c568eec0a6356491a1342a56252be210ef852494a35cfde1178bb7f18c5
#   Stored in directory: /root/.cache/pip/wheels/cd/a5/30/7b8b7f58709f5150f67f98fde4b891ebf0be9ef07a8af49f25
# Successfully built pretty_midi
# Installing collected packages: packaging, mido, pretty_midi
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed mido-1.3.2 packaging-23.2 pretty_midi-0.2.10
# Collecting midi2audio
#   Downloading midi2audio-0.1.1-py2.py3-none-any.whl (8.7 kB)
# Installing collected packages: midi2audio
# Successfully installed midi2audio-0.1.1
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
import torchaudio.transforms as transforms
import os
import re
import tensorflow as tf
import pathlib
import glob
import fluidsynth
from midi2audio import FluidSynth
import pretty_midi
from pydub import AudioSegment

# %%
def augment_pitch(pm, augment_dir, file_name, pitch_shift):
    # Apply pitch transposition

    print(f"Applying pitch shift of {pitch_shift} semitones.")
    for instrument in pm.instruments:
        for note in instrument.notes:
            note.pitch = max(0, min(127, note.pitch + pitch_shift))  # Ensure pitch is within MIDI range

    augmented_file_path = pitch_dir + f"{file_name}_pitch_{pitch_shift}.mid"

    pm.write(str(augmented_file_path))
    wav_file_path = str(augment_dir + f"{file_name}_pitch_{pitch_shift}.wav")
    FluidSynth().midi_to_audio(augmented_file_path, wav_file_path)
    clip_length(wav_file_path)

    return augmented_file_path, wav_file_path, pitch_shift

def augment_vol(pm, augment_dir, file_name, vol_shift):
  # Apply pitch transposition

  print(f"Applying volume shift of {vol_shift} velocity.")
  for instrument in pm.instruments:
      for note in instrument.notes:
          note.velocity = max(1, min(127, note.velocity + vol_shift))

  augmented_file_path = vol_dir + f"{file_name}_vol_{vol_shift}.mid"

  pm.write(str(augmented_file_path))
  wav_file_path = str(augment_dir + f"{file_name}_vol_{vol_shift}.wav")
  FluidSynth().midi_to_audio(augmented_file_path, wav_file_path)
  clip_length(wav_file_path)

  return augmented_file_path, wav_file_path, vol_shift


def augment_tempo(pm, augment_dir, file_name, tempo_shift):
  # Apply tempo transformation

  print(f"Applying tempo shift of {tempo_shift} tempo.")
  for intrument in pm.instruments:
    for note in intrument.notes:
      note.start *= tempo_shift
      note.end *= tempo_shift

  augmented_file_path = tempo_dir + f"{file_name}_tempo_{tempo_shift}.mid"
  pm.write(str(augmented_file_path))
  wav_file_path = str(augment_dir + f"{file_name}_tempo_{tempo_shift}.wav")
  FluidSynth().midi_to_audio(augmented_file_path, wav_file_path)
  clip_length(wav_file_path)

  return augmented_file_path, wav_file_path, tempo_shift

# %%
# ALTENRATIVE DATASET Lakh MIDI data layout
data_matched_dir = pathlib.Path('data/LakhMIDI')
if not data_matched_dir.exists():
  tf.keras.utils.get_file(
      'lmd_matched.tar.gz',
      origin='http://hog.ee.columbia.edu/craffel/lmd/lmd_matched.tar.gz',
      extract=True,
      cache_dir='.', cache_subdir='data',
  )

data_allgined_dir = pathlib.Path('data/LakhMIDI')
if not data_allgined_dir.exists():
  tf.keras.utils.get_file(
      'lmd_aligned.tar.gz',
      origin='http://hog.ee.columbia.edu/craffel/lmd/lmd_aligned.tar.gz',
      extract=True,
      cache_dir='.', cache_subdir='data',
  )

data_matchscores_dir = pathlib.Path('data/LakhMIDI')
if not data_allgined_dir.exists():
  tf.keras.utils.get_file(
      'match_scores.json',
      origin='http://hog.ee.columbia.edu/craffel/lmd/match_scores.json',
      extract=True,
      cache_dir='.', cache_subdir='data',
  )

# ALTENRATIVE DATASET Lakh MIDI
import json
import os

# Local path constants
DATA_PATH = "data"
RESULTS_PATH = 'data'
# Path to the file match_scores.json distributed with the LMD
score_file = 'data/match_scores.json'

# Utility functions for retrieving paths
def msd_id_to_dirs(msd_id):
    """Given an MSD ID, generate the path prefix.
    E.g. TRABCD12345678 -> A/B/C/TRABCD12345678"""
    return os.path.join(msd_id[2], msd_id[3], msd_id[4], msd_id)

def msd_id_to_mp3(msd_id):
    """Given an MSD ID, return the path to the corresponding mp3"""
    return os.path.join(DATA_PATH, 'msd', 'mp3',
                        msd_id_to_dirs(msd_id) + '.mp3')

def msd_id_to_h5(h5):
    """Given an MSD ID, return the path to the corresponding h5"""
    return os.path.join(RESULTS_PATH, 'lmd_matched_h5',
                        msd_id_to_dirs(msd_id) + '.h5')

def get_midi_path(msd_id, midi_md5, kind):
    """Given an MSD ID and MIDI MD5, return path to a MIDI file.
    kind should be one of 'matched' or 'aligned'. """
    return os.path.join('data', 'lmd_{}'.format(kind), # line might be incorrect, change later after some testing
                        msd_id_to_dirs(msd_id), midi_md5 + '.mid')

# Load the match scores to find all aligned MIDI files
def load_aligned_midi_paths(score_file, kind='aligned'):
    with open(score_file, 'r') as file:
        scores = json.load(file)

    midi_paths = []
    for msd_id, matches in scores.items():
        for midi_md5 in matches:
            midi_path = get_midi_path(msd_id, midi_md5, kind)
            midi_paths.append(midi_path)

    return midi_paths

aligned_midi_files = load_aligned_midi_paths(score_file, 'aligned')
print(aligned_midi_files)
# Out:
# Downloading data from http://hog.ee.columbia.edu/craffel/lmd/lmd_matched.tar.gz
# 1407072670/1407072670 [==============================] - 120s 0us/step
# Downloading data from http://hog.ee.columbia.edu/craffel/lmd/lmd_aligned.tar.gz
# 272169548/272169548 [==============================] - 23s 0us/step
# Downloading data from http://hog.ee.columbia.edu/craffel/lmd/match_scores.json
# 7237036/7237036 [==============================] - 1s 0us/step
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print('Number of files:', len(aligned_midi_files))
# Out:
# Number of files: 116189

# %%
gen_folder_path = r'drive/MyDrive/413/generated'
continuation_files = os.listdir(gen_folder_path)
orig_folder_path = r'drive/MyDrive/413/original/content/augmented/'
pitch_dir = r'drive/MyDrive/413/original/content/augmented/pitch/'
vol_dir = r'drive/MyDrive/413/original/content/augmented/volume/'
tempo_dir = r'drive/MyDrive/413/original/content/augmented/tempo/'
# Print the list of files
print("List of files in the folder:")

def clip_length(file, seconds=5):
  audio = AudioSegment.from_wav(file)
  if len(audio) > seconds * 1000:
    audio = audio[:seconds * 1000]
    audio.export(file, format='wav')


def get_number_of_file(filename):
    filename_parts = filename.split('_')
    match = re.search(r'_(\d+)_', filename)
    if match:
        return int(match.group(1)), filename_parts
    else:
        assert(False)
        return None

def save_as_wav(midi_file, file_name):
    wav_file_path = orig_folder_path + 'original/' + f"{file_name}.wav"
    FluidSynth().midi_to_audio(midi_file, wav_file_path)
    return wav_file_path


def make_required_augmentation(filename, name_parts):
    file_name = 'file_' + name_parts[1]
    the_file = aligned_midi_files[int(name_parts[1])]

    pm = pretty_midi.PrettyMIDI(the_file)
    if name_parts[2] == 'pitch':
        augment_pitch(pm, pitch_dir, file_name, int(name_parts[3]))
        pass
    elif name_parts[2] == 'original':
        original_wav_path = save_as_wav(the_file, file_name)
        pass
    elif name_parts[2] == 'vol':
        augment_vol(pm, vol_dir, file_name, int(name_parts[3]))
        pass
    elif name_parts[2] == 'tempo':
        augment_tempo(pm, tempo_dir, file_name, float(name_parts[3]))
    else:
        assert(False)

for file in continuation_files:
    print(file)
    num, parts = get_number_of_file(file)
    print(num)
    print(parts)
    if num > 60:
      make_required_augmentation(file, parts)
# Out:
# List of files in the folder:
# file_0_pitch_{pitch_shift}_output.wav
# 0
# ['file', '0', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_35_tempo_{tempo_shift}_output.wav
# 35
# ['file', '35', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_26_tempo_{tempo_shift}_output.wav
# 26
# ['file', '26', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_39_pitch_{pitch_shift}_output.wav
# 39
# ['file', '39', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_1_tempo_{tempo_shift}_output.wav
# 1
# ['file', '1', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_34_pitch_{pitch_shift}_output.wav
# 34
# ['file', '34', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_47_pitch_{pitch_shift}_output.wav
# 47
# ['file', '47', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_13_vol_{vol_shift}_output.wav
# 13
# ['file', '13', 'vol', '{vol', 'shift}', 'output.wav']
# file_14_vol_{vol_shift}_output.wav
# 14
# ['file', '14', 'vol', '{vol', 'shift}', 'output.wav']
# file_7_tempo_{tempo_shift}_output.wav
# 7
# ['file', '7', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_11_tempo_{tempo_shift}_output.wav
# 11
# ['file', '11', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_24_vol_{vol_shift}_output.wav
# 24
# ['file', '24', 'vol', '{vol', 'shift}', 'output.wav']
# file_18_pitch_{pitch_shift}_output.wav
# 18
# ['file', '18', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_23_original_output.wav
# 23
# ['file', '23', 'original', 'output.wav']
# file_42_tempo_{tempo_shift}_output.wav
# 42
# ['file', '42', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_29_tempo_{tempo_shift}_output.wav
# 29
# ['file', '29', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_39_vol_{vol_shift}_output.wav
# 39
# ['file', '39', 'vol', '{vol', 'shift}', 'output.wav']
# file_33_vol_{vol_shift}_output.wav
# 33
# ['file', '33', 'vol', '{vol', 'shift}', 'output.wav']
# file_3_pitch_{pitch_shift}_output.wav
# 3
# ['file', '3', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_18_tempo_{tempo_shift}_output.wav
# 18
# ['file', '18', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_44_pitch_{pitch_shift}_output.wav
# 44
# ['file', '44', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_32_original_output.wav
# 32
# ['file', '32', 'original', 'output.wav']
# file_2_pitch_{pitch_shift}_output.wav
# 2
# ['file', '2', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_45_pitch_{pitch_shift}_output.wav
# 45
# ['file', '45', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_22_pitch_{pitch_shift}_output.wav
# 22
# ['file', '22', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_10_tempo_{tempo_shift}_output.wav
# 10
# ['file', '10', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_22_original_output.wav
# 22
# ['file', '22', 'original', 'output.wav']
# file_25_tempo_{tempo_shift}_output.wav
# 25
# ['file', '25', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_31_tempo_{tempo_shift}_output.wav
# 31
# ['file', '31', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_27_original_output.wav
# 27
# ['file', '27', 'original', 'output.wav']
# file_41_original_output.wav
# 41
# ['file', '41', 'original', 'output.wav']
# file_44_original_output.wav
# 44
# ['file', '44', 'original', 'output.wav']
# file_51_original_output.wav
# 51
# ['file', '51', 'original', 'output.wav']
# file_11_vol_{vol_shift}_output.wav
# 11
# ['file', '11', 'vol', '{vol', 'shift}', 'output.wav']
# file_0_original_output.wav
# 0
# ['file', '0', 'original', 'output.wav']
# file_4_original_output.wav
# 4
# ['file', '4', 'original', 'output.wav']
# file_24_original_output.wav
# 24
# ['file', '24', 'original', 'output.wav']
# file_22_vol_{vol_shift}_output.wav
# 22
# ['file', '22', 'vol', '{vol', 'shift}', 'output.wav']
# file_12_tempo_{tempo_shift}_output.wav
# 12
# ['file', '12', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_21_original_output.wav
# 21
# ['file', '21', 'original', 'output.wav']
# file_29_vol_{vol_shift}_output.wav
# 29
# ['file', '29', 'vol', '{vol', 'shift}', 'output.wav']
# file_49_vol_{vol_shift}_output.wav
# 49
# ['file', '49', 'vol', '{vol', 'shift}', 'output.wav']
# file_20_pitch_{pitch_shift}_output.wav
# 20
# ['file', '20', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_19_vol_{vol_shift}_output.wav
# 19
# ['file', '19', 'vol', '{vol', 'shift}', 'output.wav']
# file_8_vol_{vol_shift}_output.wav
# 8
# ['file', '8', 'vol', '{vol', 'shift}', 'output.wav']
# file_23_tempo_{tempo_shift}_output.wav
# 23
# ['file', '23', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_45_original_output.wav
# 45
# ['file', '45', 'original', 'output.wav']
# file_27_tempo_{tempo_shift}_output.wav
# 27
# ['file', '27', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_37_original_output.wav
# 37
# ['file', '37', 'original', 'output.wav']
# file_15_original_output.wav
# 15
# ['file', '15', 'original', 'output.wav']
# file_40_tempo_{tempo_shift}_output.wav
# 40
# ['file', '40', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_9_tempo_{tempo_shift}_output.wav
# 9
# ['file', '9', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_51_vol_{vol_shift}_output.wav
# 51
# ['file', '51', 'vol', '{vol', 'shift}', 'output.wav']
# file_46_vol_{vol_shift}_output.wav
# 46
# ['file', '46', 'vol', '{vol', 'shift}', 'output.wav']
# file_6_original_output.wav
# 6
# ['file', '6', 'original', 'output.wav']
# file_22_tempo_{tempo_shift}_output.wav
# 22
# ['file', '22', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_12_vol_{vol_shift}_output.wav
# 12
# ['file', '12', 'vol', '{vol', 'shift}', 'output.wav']
# file_15_pitch_{pitch_shift}_output.wav
# 15
# ['file', '15', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_7_pitch_{pitch_shift}_output.wav
# 7
# ['file', '7', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_36_tempo_{tempo_shift}_output.wav
# 36
# ['file', '36', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_48_vol_{vol_shift}_output.wav
# 48
# ['file', '48', 'vol', '{vol', 'shift}', 'output.wav']
# file_29_original_output.wav
# 29
# ['file', '29', 'original', 'output.wav']
# file_37_vol_{vol_shift}_output.wav
# 37
# ['file', '37', 'vol', '{vol', 'shift}', 'output.wav']
# file_46_tempo_{tempo_shift}_output.wav
# 46
# ['file', '46', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_30_original_output.wav
# 30
# ['file', '30', 'original', 'output.wav']
# file_13_tempo_{tempo_shift}_output.wav
# 13
# ['file', '13', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_26_vol_{vol_shift}_output.wav
# 26
# ['file', '26', 'vol', '{vol', 'shift}', 'output.wav']
# file_7_original_output.wav
# 7
# ['file', '7', 'original', 'output.wav']
# file_16_pitch_{pitch_shift}_output.wav
# 16
# ['file', '16', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_39_original_output.wav
# 39
# ['file', '39', 'original', 'output.wav']
# file_33_original_output.wav
# 33
# ['file', '33', 'original', 'output.wav']
# file_45_tempo_{tempo_shift}_output.wav
# 45
# ['file', '45', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_48_pitch_{pitch_shift}_output.wav
# 48
# ['file', '48', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_40_pitch_{pitch_shift}_output.wav
# 40
# ['file', '40', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_3_vol_{vol_shift}_output.wav
# 3
# ['file', '3', 'vol', '{vol', 'shift}', 'output.wav']
# file_13_original_output.wav
# 13
# ['file', '13', 'original', 'output.wav']
# file_42_pitch_{pitch_shift}_output.wav
# 42
# ['file', '42', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_41_tempo_{tempo_shift}_output.wav
# 41
# ['file', '41', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_7_vol_{vol_shift}_output.wav
# 7
# ['file', '7', 'vol', '{vol', 'shift}', 'output.wav']
# file_14_tempo_{tempo_shift}_output.wav
# 14
# ['file', '14', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_4_vol_{vol_shift}_output.wav
# 4
# ['file', '4', 'vol', '{vol', 'shift}', 'output.wav']
# file_35_vol_{vol_shift}_output.wav
# 35
# ['file', '35', 'vol', '{vol', 'shift}', 'output.wav']
# file_43_tempo_{tempo_shift}_output.wav
# 43
# ['file', '43', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_34_vol_{vol_shift}_output.wav
# 34
# ['file', '34', 'vol', '{vol', 'shift}', 'output.wav']
# file_18_vol_{vol_shift}_output.wav
# 18
# ['file', '18', 'vol', '{vol', 'shift}', 'output.wav']
# file_35_pitch_{pitch_shift}_output.wav
# 35
# ['file', '35', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_38_tempo_{tempo_shift}_output.wav
# 38
# ['file', '38', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_40_vol_{vol_shift}_output.wav
# 40
# ['file', '40', 'vol', '{vol', 'shift}', 'output.wav']
# file_33_pitch_{pitch_shift}_output.wav
# 33
# ['file', '33', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_28_tempo_{tempo_shift}_output.wav
# 28
# ['file', '28', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_19_original_output.wav
# 19
# ['file', '19', 'original', 'output.wav']
# file_41_vol_{vol_shift}_output.wav
# 41
# ['file', '41', 'vol', '{vol', 'shift}', 'output.wav']
# file_38_pitch_{pitch_shift}_output.wav
# 38
# ['file', '38', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_10_original_output.wav
# 10
# ['file', '10', 'original', 'output.wav']
# file_24_tempo_{tempo_shift}_output.wav
# 24
# ['file', '24', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_48_original_output.wav
# 48
# ['file', '48', 'original', 'output.wav']
# file_5_vol_{vol_shift}_output.wav
# 5
# ['file', '5', 'vol', '{vol', 'shift}', 'output.wav']
# file_9_original_output.wav
# 9
# ['file', '9', 'original', 'output.wav']
# file_10_vol_{vol_shift}_output.wav
# 10
# ['file', '10', 'vol', '{vol', 'shift}', 'output.wav']
# file_14_pitch_{pitch_shift}_output.wav
# 14
# ['file', '14', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_20_original_output.wav
# 20
# ['file', '20', 'original', 'output.wav']
# file_25_pitch_{pitch_shift}_output.wav
# 25
# ['file', '25', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_26_original_output.wav
# 26
# ['file', '26', 'original', 'output.wav']
# file_10_pitch_{pitch_shift}_output.wav
# 10
# ['file', '10', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_2_tempo_{tempo_shift}_output.wav
# 2
# ['file', '2', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_38_original_output.wav
# 38
# ['file', '38', 'original', 'output.wav']
# file_6_tempo_{tempo_shift}_output.wav
# 6
# ['file', '6', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_44_tempo_{tempo_shift}_output.wav
# 44
# ['file', '44', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_5_original_output.wav
# 5
# ['file', '5', 'original', 'output.wav']
# file_45_vol_{vol_shift}_output.wav
# 45
# ['file', '45', 'vol', '{vol', 'shift}', 'output.wav']
# file_36_pitch_{pitch_shift}_output.wav
# 36
# ['file', '36', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_30_tempo_{tempo_shift}_output.wav
# 30
# ['file', '30', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_21_vol_{vol_shift}_output.wav
# 21
# ['file', '21', 'vol', '{vol', 'shift}', 'output.wav']
# file_32_pitch_{pitch_shift}_output.wav
# 32
# ['file', '32', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_43_pitch_{pitch_shift}_output.wav
# 43
# ['file', '43', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_23_vol_{vol_shift}_output.wav
# 23
# ['file', '23', 'vol', '{vol', 'shift}', 'output.wav']
# file_25_original_output.wav
# 25
# ['file', '25', 'original', 'output.wav']
# file_11_original_output.wav
# 11
# ['file', '11', 'original', 'output.wav']
# file_15_vol_{vol_shift}_output.wav
# 15
# ['file', '15', 'vol', '{vol', 'shift}', 'output.wav']
# file_11_pitch_{pitch_shift}_output.wav
# 11
# ['file', '11', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_16_tempo_{tempo_shift}_output.wav
# 16
# ['file', '16', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_9_vol_{vol_shift}_output.wav
# 9
# ['file', '9', 'vol', '{vol', 'shift}', 'output.wav']
# file_51_tempo_{tempo_shift}_output.wav
# 51
# ['file', '51', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_21_pitch_{pitch_shift}_output.wav
# 21
# ['file', '21', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_4_tempo_{tempo_shift}_output.wav
# 4
# ['file', '4', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_4_pitch_{pitch_shift}_output.wav
# 4
# ['file', '4', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_3_tempo_{tempo_shift}_output.wav
# 3
# ['file', '3', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_32_tempo_{tempo_shift}_output.wav
# 32
# ['file', '32', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_32_vol_{vol_shift}_output.wav
# 32
# ['file', '32', 'vol', '{vol', 'shift}', 'output.wav']
# file_38_vol_{vol_shift}_output.wav
# 38
# ['file', '38', 'vol', '{vol', 'shift}', 'output.wav']
# file_20_vol_{vol_shift}_output.wav
# 20
# ['file', '20', 'vol', '{vol', 'shift}', 'output.wav']
# file_47_original_output.wav
# 47
# ['file', '47', 'original', 'output.wav']
# file_15_tempo_{tempo_shift}_output.wav
# 15
# ['file', '15', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_27_vol_{vol_shift}_output.wav
# 27
# ['file', '27', 'vol', '{vol', 'shift}', 'output.wav']
# file_43_original_output.wav
# 43
# ['file', '43', 'original', 'output.wav']
# file_17_pitch_{pitch_shift}_output.wav
# 17
# ['file', '17', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_16_vol_{vol_shift}_output.wav
# 16
# ['file', '16', 'vol', '{vol', 'shift}', 'output.wav']
# file_37_pitch_{pitch_shift}_output.wav
# 37
# ['file', '37', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_2_vol_{vol_shift}_output.wav
# 2
# ['file', '2', 'vol', '{vol', 'shift}', 'output.wav']
# file_31_pitch_{pitch_shift}_output.wav
# 31
# ['file', '31', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_5_pitch_{pitch_shift}_output.wav
# 5
# ['file', '5', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_34_original_output.wav
# 34
# ['file', '34', 'original', 'output.wav']
# file_3_original_output.wav
# 3
# ['file', '3', 'original', 'output.wav']
# file_1_original_output.wav
# 1
# ['file', '1', 'original', 'output.wav']
# file_8_pitch_{pitch_shift}_output.wav
# 8
# ['file', '8', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_31_original_output.wav
# 31
# ['file', '31', 'original', 'output.wav']
# file_29_pitch_{pitch_shift}_output.wav
# 29
# ['file', '29', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_16_original_output.wav
# 16
# ['file', '16', 'original', 'output.wav']
# file_33_tempo_{tempo_shift}_output.wav
# 33
# ['file', '33', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_18_original_output.wav
# 18
# ['file', '18', 'original', 'output.wav']
# file_1_pitch_{pitch_shift}_output.wav
# 1
# ['file', '1', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_46_original_output.wav
# 46
# ['file', '46', 'original', 'output.wav']
# file_25_vol_{vol_shift}_output.wav
# 25
# ['file', '25', 'vol', '{vol', 'shift}', 'output.wav']
# file_48_tempo_{tempo_shift}_output.wav
# 48
# ['file', '48', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_14_original_output.wav
# 14
# ['file', '14', 'original', 'output.wav']
# file_12_original_output.wav
# 12
# ['file', '12', 'original', 'output.wav']
# file_34_tempo_{tempo_shift}_output.wav
# 34
# ['file', '34', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_23_pitch_{pitch_shift}_output.wav
# 23
# ['file', '23', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_44_vol_{vol_shift}_output.wav
# 44
# ['file', '44', 'vol', '{vol', 'shift}', 'output.wav']
# file_40_original_output.wav
# 40
# ['file', '40', 'original', 'output.wav']
# file_20_tempo_{tempo_shift}_output.wav
# 20
# ['file', '20', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_42_vol_{vol_shift}_output.wav
# 42
# ['file', '42', 'vol', '{vol', 'shift}', 'output.wav']
# file_8_original_output.wav
# 8
# ['file', '8', 'original', 'output.wav']
# file_19_pitch_{pitch_shift}_output.wav
# 19
# ['file', '19', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_26_pitch_{pitch_shift}_output.wav
# 26
# ['file', '26', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_17_vol_{vol_shift}_output.wav
# 17
# ['file', '17', 'vol', '{vol', 'shift}', 'output.wav']
# file_51_pitch_{pitch_shift}_output.wav
# 51
# ['file', '51', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_36_original_output.wav
# 36
# ['file', '36', 'original', 'output.wav']
# file_28_pitch_{pitch_shift}_output.wav
# 28
# ['file', '28', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_1_vol_{vol_shift}_output.wav
# 1
# ['file', '1', 'vol', '{vol', 'shift}', 'output.wav']
# file_6_vol_{vol_shift}_output.wav
# 6
# ['file', '6', 'vol', '{vol', 'shift}', 'output.wav']
# file_47_vol_{vol_shift}_output.wav
# 47
# ['file', '47', 'vol', '{vol', 'shift}', 'output.wav']
# file_49_pitch_{pitch_shift}_output.wav
# 49
# ['file', '49', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_30_pitch_{pitch_shift}_output.wav
# 30
# ['file', '30', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_24_pitch_{pitch_shift}_output.wav
# 24
# ['file', '24', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_35_original_output.wav
# 35
# ['file', '35', 'original', 'output.wav']
# file_6_pitch_{pitch_shift}_output.wav
# 6
# ['file', '6', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_5_tempo_{tempo_shift}_output.wav
# 5
# ['file', '5', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_42_original_output.wav
# 42
# ['file', '42', 'original', 'output.wav']
# file_8_tempo_{tempo_shift}_output.wav
# 8
# ['file', '8', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_0_tempo_{tempo_shift}_output.wav
# 0
# ['file', '0', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_46_pitch_{pitch_shift}_output.wav
# 46
# ['file', '46', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_39_tempo_{tempo_shift}_output.wav
# 39
# ['file', '39', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_49_tempo_{tempo_shift}_output.wav
# 49
# ['file', '49', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_27_pitch_{pitch_shift}_output.wav
# 27
# ['file', '27', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_47_tempo_{tempo_shift}_output.wav
# 47
# ['file', '47', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_21_tempo_{tempo_shift}_output.wav
# 21
# ['file', '21', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_31_vol_{vol_shift}_output.wav
# 31
# ['file', '31', 'vol', '{vol', 'shift}', 'output.wav']
# file_19_tempo_{tempo_shift}_output.wav
# 19
# ['file', '19', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_13_pitch_{pitch_shift}_output.wav
# 13
# ['file', '13', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_12_pitch_{pitch_shift}_output.wav
# 12
# ['file', '12', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_2_original_output.wav
# 2
# ['file', '2', 'original', 'output.wav']
# file_0_vol_{vol_shift}_output.wav
# 0
# ['file', '0', 'vol', '{vol', 'shift}', 'output.wav']
# file_28_original_output.wav
# 28
# ['file', '28', 'original', 'output.wav']
# file_30_vol_{vol_shift}_output.wav
# 30
# ['file', '30', 'vol', '{vol', 'shift}', 'output.wav']
# file_37_tempo_{tempo_shift}_output.wav
# 37
# ['file', '37', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_49_original_output.wav
# 49
# ['file', '49', 'original', 'output.wav']
# file_9_pitch_{pitch_shift}_output.wav
# 9
# ['file', '9', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_17_tempo_{tempo_shift}_output.wav
# 17
# ['file', '17', 'tempo', '{tempo', 'shift}', 'output.wav']
# file_17_original_output.wav
# 17
# ['file', '17', 'original', 'output.wav']
# file_43_vol_{vol_shift}_output.wav
# 43
# ['file', '43', 'vol', '{vol', 'shift}', 'output.wav']
# file_41_pitch_{pitch_shift}_output.wav
# 41
# ['file', '41', 'pitch', '{pitch', 'shift}', 'output.wav']
# file_28_vol_{vol_shift}_output.wav
# 28
# ['file', '28', 'vol', '{vol', 'shift}', 'output.wav']
# file_36_vol_{vol_shift}_output.wav
# 36
# ['file', '36', 'vol', '{vol', 'shift}', 'output.wav']
# file_103_original_output.wav
# 103
# ['file', '103', 'original', 'output.wav']
# file_113_pitch_0_output.wav
# 113
# ['file', '113', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_159_tempo_0.75_output.wav
# 159
# ['file', '159', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_184_pitch_3_output.wav
# 184
# ['file', '184', 'pitch', '3', 'output.wav']
# Applying pitch shift of 3 semitones.
# file_127_pitch_-3_output.wav
# 127
# ['file', '127', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_134_pitch_-4_output.wav
# 134
# ['file', '134', 'pitch', '-4', 'output.wav']
# Applying pitch shift of -4 semitones.
# file_182_vol_19_output.wav
# 182
# ['file', '182', 'vol', '19', 'output.wav']
# Applying volume shift of 19 velocity.
# file_158_tempo_0.25_output.wav
# 158
# ['file', '158', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_191_original_output.wav
# 191
# ['file', '191', 'original', 'output.wav']
# file_189_pitch_-5_output.wav
# 189
# ['file', '189', 'pitch', '-5', 'output.wav']
# Applying pitch shift of -5 semitones.
# file_117_tempo_0.75_output.wav
# 117
# ['file', '117', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_118_pitch_4_output.wav
# 118
# ['file', '118', 'pitch', '4', 'output.wav']
# Applying pitch shift of 4 semitones.
# file_134_vol_-16_output.wav
# 134
# ['file', '134', 'vol', '-16', 'output.wav']
# Applying volume shift of -16 velocity.
# file_164_tempo_1.5_output.wav
# 164
# ['file', '164', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_175_original_output.wav
# 175
# ['file', '175', 'original', 'output.wav']
# file_146_original_output.wav
# 146
# ['file', '146', 'original', 'output.wav']
# file_126_tempo_1.5_output.wav
# 126
# ['file', '126', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_171_pitch_-1_output.wav
# 171
# ['file', '171', 'pitch', '-1', 'output.wav']
# Applying pitch shift of -1 semitones.
# file_171_vol_7_output.wav
# 171
# ['file', '171', 'vol', '7', 'output.wav']
# Applying volume shift of 7 velocity.
# file_137_pitch_-3_output.wav
# 137
# ['file', '137', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_111_tempo_0.5_output.wav
# 111
# ['file', '111', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_186_original_output.wav
# 186
# ['file', '186', 'original', 'output.wav']
# file_129_pitch_-1_output.wav
# 129
# ['file', '129', 'pitch', '-1', 'output.wav']
# Applying pitch shift of -1 semitones.
# file_203_original_output.wav
# 203
# ['file', '203', 'original', 'output.wav']
# file_153_vol_-9_output.wav
# 153
# ['file', '153', 'vol', '-9', 'output.wav']
# Applying volume shift of -9 velocity.
# file_167_original_output.wav
# 167
# ['file', '167', 'original', 'output.wav']
# file_188_vol_-27_output.wav
# 188
# ['file', '188', 'vol', '-27', 'output.wav']
# Applying volume shift of -27 velocity.
# file_122_vol_10_output.wav
# 122
# ['file', '122', 'vol', '10', 'output.wav']
# Applying volume shift of 10 velocity.
# file_142_tempo_0.75_output.wav
# 142
# ['file', '142', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_137_vol_-9_output.wav
# 137
# ['file', '137', 'vol', '-9', 'output.wav']
# Applying volume shift of -9 velocity.
# file_151_original_output.wav
# 151
# ['file', '151', 'original', 'output.wav']
# file_199_vol_21_output.wav
# 199
# ['file', '199', 'vol', '21', 'output.wav']
# Applying volume shift of 21 velocity.
# file_181_pitch_4_output.wav
# 181
# ['file', '181', 'pitch', '4', 'output.wav']
# Applying pitch shift of 4 semitones.
# file_156_pitch_1_output.wav
# 156
# ['file', '156', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_101_original_output.wav
# 101
# ['file', '101', 'original', 'output.wav']
# file_138_pitch_-2_output.wav
# 138
# ['file', '138', 'pitch', '-2', 'output.wav']
# Applying pitch shift of -2 semitones.
# file_162_original_output.wav
# 162
# ['file', '162', 'original', 'output.wav']
# file_145_pitch_6_output.wav
# 145
# ['file', '145', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_197_tempo_0.5_output.wav
# 197
# ['file', '197', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_110_original_output.wav
# 110
# ['file', '110', 'original', 'output.wav']
# file_138_vol_-13_output.wav
# 138
# ['file', '138', 'vol', '-13', 'output.wav']
# Applying volume shift of -13 velocity.
# file_187_original_output.wav
# 187
# ['file', '187', 'original', 'output.wav']
# file_150_tempo_0.25_output.wav
# 150
# ['file', '150', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_146_vol_21_output.wav
# 146
# ['file', '146', 'vol', '21', 'output.wav']
# Applying volume shift of 21 velocity.
# file_128_vol_30_output.wav
# 128
# ['file', '128', 'vol', '30', 'output.wav']
# Applying volume shift of 30 velocity.
# file_165_vol_-10_output.wav
# 165
# ['file', '165', 'vol', '-10', 'output.wav']
# Applying volume shift of -10 velocity.
# file_194_original_output.wav
# 194
# ['file', '194', 'original', 'output.wav']
# file_124_tempo_0.25_output.wav
# 124
# ['file', '124', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_190_tempo_1.25_output.wav
# 190
# ['file', '190', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_105_tempo_0.75_output.wav
# 105
# ['file', '105', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_167_vol_0_output.wav
# 167
# ['file', '167', 'vol', '0', 'output.wav']
# Applying volume shift of 0 velocity.
# file_184_vol_24_output.wav
# 184
# ['file', '184', 'vol', '24', 'output.wav']
# Applying volume shift of 24 velocity.
# file_146_tempo_0.5_output.wav
# 146
# ['file', '146', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_198_tempo_1.5_output.wav
# 198
# ['file', '198', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_191_tempo_1.25_output.wav
# 191
# ['file', '191', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_106_original_output.wav
# 106
# ['file', '106', 'original', 'output.wav']
# file_118_vol_-22_output.wav
# 118
# ['file', '118', 'vol', '-22', 'output.wav']
# Applying volume shift of -22 velocity.
# file_114_vol_-5_output.wav
# 114
# ['file', '114', 'vol', '-5', 'output.wav']
# Applying volume shift of -5 velocity.
# file_139_pitch_1_output.wav
# 139
# ['file', '139', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_137_tempo_1.75_output.wav
# 137
# ['file', '137', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_133_tempo_0.5_output.wav
# 133
# ['file', '133', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_143_pitch_4_output.wav
# 143
# ['file', '143', 'pitch', '4', 'output.wav']
# Applying pitch shift of 4 semitones.
# file_110_tempo_1.5_output.wav
# 110
# ['file', '110', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_116_pitch_1_output.wav
# 116
# ['file', '116', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_205_original_output.wav
# 205
# ['file', '205', 'original', 'output.wav']
# file_204_pitch_2_output.wav
# 204
# ['file', '204', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_178_tempo_1.25_output.wav
# 178
# ['file', '178', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_187_vol_1_output.wav
# 187
# ['file', '187', 'vol', '1', 'output.wav']
# Applying volume shift of 1 velocity.
# file_145_vol_-10_output.wav
# 145
# ['file', '145', 'vol', '-10', 'output.wav']
# Applying volume shift of -10 velocity.
# file_179_original_output.wav
# 179
# ['file', '179', 'original', 'output.wav']
# file_189_tempo_0.5_output.wav
# 189
# ['file', '189', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_123_tempo_0.25_output.wav
# 123
# ['file', '123', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_117_vol_28_output.wav
# 117
# ['file', '117', 'vol', '28', 'output.wav']
# Applying volume shift of 28 velocity.
# file_143_tempo_0.5_output.wav
# 143
# ['file', '143', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_172_vol_-4_output.wav
# 172
# ['file', '172', 'vol', '-4', 'output.wav']
# Applying volume shift of -4 velocity.
# file_172_tempo_1.25_output.wav
# 172
# ['file', '172', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_133_vol_-22_output.wav
# 133
# ['file', '133', 'vol', '-22', 'output.wav']
# Applying volume shift of -22 velocity.
# file_164_pitch_-6_output.wav
# 164
# ['file', '164', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_147_original_output.wav
# 147
# ['file', '147', 'original', 'output.wav']
# file_170_original_output.wav
# 170
# ['file', '170', 'original', 'output.wav']
# file_180_tempo_0.5_output.wav
# 180
# ['file', '180', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_187_pitch_-4_output.wav
# 187
# ['file', '187', 'pitch', '-4', 'output.wav']
# Applying pitch shift of -4 semitones.
# file_128_pitch_0_output.wav
# 128
# ['file', '128', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_171_original_output.wav
# 171
# ['file', '171', 'original', 'output.wav']
# file_148_tempo_0.25_output.wav
# 148
# ['file', '148', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_166_pitch_5_output.wav
# 166
# ['file', '166', 'pitch', '5', 'output.wav']
# Applying pitch shift of 5 semitones.
# file_125_tempo_0.75_output.wav
# 125
# ['file', '125', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_131_pitch_-3_output.wav
# 131
# ['file', '131', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_100_tempo_1.5_output.wav
# 100
# ['file', '100', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_183_tempo_1.75_output.wav
# 183
# ['file', '183', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_140_original_output.wav
# 140
# ['file', '140', 'original', 'output.wav']
# file_138_tempo_1.5_output.wav
# 138
# ['file', '138', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_171_tempo_1.25_output.wav
# 171
# ['file', '171', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_198_vol_-28_output.wav
# 198
# ['file', '198', 'vol', '-28', 'output.wav']
# Applying volume shift of -28 velocity.
# file_109_tempo_0.75_output.wav
# 109
# ['file', '109', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_196_tempo_1.75_output.wav
# 196
# ['file', '196', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_125_original_output.wav
# 125
# ['file', '125', 'original', 'output.wav']
# file_193_original_output.wav
# 193
# ['file', '193', 'original', 'output.wav']
# file_148_vol_-5_output.wav
# 148
# ['file', '148', 'vol', '-5', 'output.wav']
# Applying volume shift of -5 velocity.
# file_118_original_output.wav
# 118
# ['file', '118', 'original', 'output.wav']
# file_153_pitch_-3_output.wav
# 153
# ['file', '153', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_136_vol_13_output.wav
# 136
# ['file', '136', 'vol', '13', 'output.wav']
# Applying volume shift of 13 velocity.
# file_165_pitch_2_output.wav
# 165
# ['file', '165', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_174_vol_4_output.wav
# 174
# ['file', '174', 'vol', '4', 'output.wav']
# Applying volume shift of 4 velocity.
# file_181_vol_-17_output.wav
# 181
# ['file', '181', 'vol', '-17', 'output.wav']
# Applying volume shift of -17 velocity.
# file_159_original_output.wav
# 159
# ['file', '159', 'original', 'output.wav']
# file_150_vol_15_output.wav
# 150
# ['file', '150', 'vol', '15', 'output.wav']
# Applying volume shift of 15 velocity.
# file_177_vol_10_output.wav
# 177
# ['file', '177', 'vol', '10', 'output.wav']
# Applying volume shift of 10 velocity.
# file_131_tempo_0.25_output.wav
# 131
# ['file', '131', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_189_original_output.wav
# 189
# ['file', '189', 'original', 'output.wav']
# file_126_pitch_0_output.wav
# 126
# ['file', '126', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_126_original_output.wav
# 126
# ['file', '126', 'original', 'output.wav']
# file_201_original_output.wav
# 201
# ['file', '201', 'original', 'output.wav']
# file_195_tempo_1.25_output.wav
# 195
# ['file', '195', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_176_vol_20_output.wav
# 176
# ['file', '176', 'vol', '20', 'output.wav']
# Applying volume shift of 20 velocity.
# file_120_vol_-9_output.wav
# 120
# ['file', '120', 'vol', '-9', 'output.wav']
# Applying volume shift of -9 velocity.
# file_204_tempo_1.5_output.wav
# 204
# ['file', '204', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_102_tempo_1.75_output.wav
# 102
# ['file', '102', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_191_vol_-3_output.wav
# 191
# ['file', '191', 'vol', '-3', 'output.wav']
# Applying volume shift of -3 velocity.
# file_121_pitch_5_output.wav
# 121
# ['file', '121', 'pitch', '5', 'output.wav']
# Applying pitch shift of 5 semitones.
# file_101_pitch_-1_output.wav
# 101
# ['file', '101', 'pitch', '-1', 'output.wav']
# Applying pitch shift of -1 semitones.
# file_144_pitch_1_output.wav
# 144
# ['file', '144', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_169_pitch_1_output.wav
# 169
# ['file', '169', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_112_vol_-25_output.wav
# 112
# ['file', '112', 'vol', '-25', 'output.wav']
# Applying volume shift of -25 velocity.
# file_154_vol_28_output.wav
# 154
# ['file', '154', 'vol', '28', 'output.wav']
# Applying volume shift of 28 velocity.
# file_135_tempo_1.25_output.wav
# 135
# ['file', '135', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_136_tempo_0.75_output.wav
# 136
# ['file', '136', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_102_original_output.wav
# 102
# ['file', '102', 'original', 'output.wav']
# file_161_original_output.wav
# 161
# ['file', '161', 'original', 'output.wav']
# file_123_pitch_5_output.wav
# 123
# ['file', '123', 'pitch', '5', 'output.wav']
# Applying pitch shift of 5 semitones.
# file_204_original_output.wav
# 204
# ['file', '204', 'original', 'output.wav']
# file_165_tempo_1.75_output.wav
# 165
# ['file', '165', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_205_pitch_4_output.wav
# 205
# ['file', '205', 'pitch', '4', 'output.wav']
# Applying pitch shift of 4 semitones.
# file_191_pitch_4_output.wav
# 191
# ['file', '191', 'pitch', '4', 'output.wav']
# Applying pitch shift of 4 semitones.
# file_139_original_output.wav
# 139
# ['file', '139', 'original', 'output.wav']
# file_160_vol_14_output.wav
# 160
# ['file', '160', 'vol', '14', 'output.wav']
# Applying volume shift of 14 velocity.
# file_113_vol_-21_output.wav
# 113
# ['file', '113', 'vol', '-21', 'output.wav']
# Applying volume shift of -21 velocity.
# file_128_tempo_0.5_output.wav
# 128
# ['file', '128', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_153_original_output.wav
# 153
# ['file', '153', 'original', 'output.wav']
# file_109_vol_30_output.wav
# 109
# ['file', '109', 'vol', '30', 'output.wav']
# Applying volume shift of 30 velocity.
# file_117_original_output.wav
# 117
# ['file', '117', 'original', 'output.wav']
# file_154_pitch_3_output.wav
# 154
# ['file', '154', 'pitch', '3', 'output.wav']
# Applying pitch shift of 3 semitones.
# file_157_vol_-16_output.wav
# 157
# ['file', '157', 'vol', '-16', 'output.wav']
# Applying volume shift of -16 velocity.
# file_200_pitch_1_output.wav
# 200
# ['file', '200', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_102_pitch_2_output.wav
# 102
# ['file', '102', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_105_vol_-3_output.wav
# 105
# ['file', '105', 'vol', '-3', 'output.wav']
# Applying volume shift of -3 velocity.
# file_123_vol_-13_output.wav
# 123
# ['file', '123', 'vol', '-13', 'output.wav']
# Applying volume shift of -13 velocity.
# file_196_pitch_1_output.wav
# 196
# ['file', '196', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_164_vol_-11_output.wav
# 164
# ['file', '164', 'vol', '-11', 'output.wav']
# Applying volume shift of -11 velocity.
# file_100_vol_-18_output.wav
# 100
# ['file', '100', 'vol', '-18', 'output.wav']
# Applying volume shift of -18 velocity.
# file_137_original_output.wav
# 137
# ['file', '137', 'original', 'output.wav']
# file_125_vol_16_output.wav
# 125
# ['file', '125', 'vol', '16', 'output.wav']
# Applying volume shift of 16 velocity.
# file_159_pitch_-1_output.wav
# 159
# ['file', '159', 'pitch', '-1', 'output.wav']
# Applying pitch shift of -1 semitones.
# file_103_pitch_4_output.wav
# 103
# ['file', '103', 'pitch', '4', 'output.wav']
# Applying pitch shift of 4 semitones.
# file_176_original_output.wav
# 176
# ['file', '176', 'original', 'output.wav']
# file_160_original_output.wav
# 160
# ['file', '160', 'original', 'output.wav']
# file_134_tempo_1.75_output.wav
# 134
# ['file', '134', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_151_pitch_4_output.wav
# 151
# ['file', '151', 'pitch', '4', 'output.wav']
# Applying pitch shift of 4 semitones.
# file_166_tempo_0.25_output.wav
# 166
# ['file', '166', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_172_pitch_-6_output.wav
# 172
# ['file', '172', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_169_tempo_1.5_output.wav
# 169
# ['file', '169', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_205_tempo_0.5_output.wav
# 205
# ['file', '205', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_112_tempo_0.25_output.wav
# 112
# ['file', '112', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_192_pitch_6_output.wav
# 192
# ['file', '192', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_164_original_output.wav
# 164
# ['file', '164', 'original', 'output.wav']
# file_149_tempo_1.25_output.wav
# 149
# ['file', '149', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_181_original_output.wav
# 181
# ['file', '181', 'original', 'output.wav']
# file_115_tempo_0.75_output.wav
# 115
# ['file', '115', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_169_original_output.wav
# 169
# ['file', '169', 'original', 'output.wav']
# file_190_original_output.wav
# 190
# ['file', '190', 'original', 'output.wav']
# file_127_tempo_0.5_output.wav
# 127
# ['file', '127', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_202_tempo_1.5_output.wav
# 202
# ['file', '202', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_178_vol_-15_output.wav
# 178
# ['file', '178', 'vol', '-15', 'output.wav']
# Applying volume shift of -15 velocity.
# file_106_pitch_-4_output.wav
# 106
# ['file', '106', 'pitch', '-4', 'output.wav']
# Applying pitch shift of -4 semitones.
# file_186_tempo_1.75_output.wav
# 186
# ['file', '186', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_160_tempo_0.75_output.wav
# 160
# ['file', '160', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_183_original_output.wav
# 183
# ['file', '183', 'original', 'output.wav']
# file_145_tempo_0.25_output.wav
# 145
# ['file', '145', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_130_pitch_0_output.wav
# 130
# ['file', '130', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_179_tempo_0.5_output.wav
# 179
# ['file', '179', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_152_original_output.wav
# 152
# ['file', '152', 'original', 'output.wav']
# file_111_vol_5_output.wav
# 111
# ['file', '111', 'vol', '5', 'output.wav']
# Applying volume shift of 5 velocity.
# file_198_pitch_1_output.wav
# 198
# ['file', '198', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_203_vol_14_output.wav
# 203
# ['file', '203', 'vol', '14', 'output.wav']
# Applying volume shift of 14 velocity.
# file_105_pitch_2_output.wav
# 105
# ['file', '105', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_110_pitch_-4_output.wav
# 110
# ['file', '110', 'pitch', '-4', 'output.wav']
# Applying pitch shift of -4 semitones.
# file_185_original_output.wav
# 185
# ['file', '185', 'original', 'output.wav']
# file_162_tempo_1.5_output.wav
# 162
# ['file', '162', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_121_tempo_1.5_output.wav
# 121
# ['file', '121', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_142_vol_28_output.wav
# 142
# ['file', '142', 'vol', '28', 'output.wav']
# Applying volume shift of 28 velocity.
# file_150_pitch_-3_output.wav
# 150
# ['file', '150', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_114_tempo_1.75_output.wav
# 114
# ['file', '114', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_110_vol_-25_output.wav
# 110
# ['file', '110', 'vol', '-25', 'output.wav']
# Applying volume shift of -25 velocity.
# file_192_tempo_1.75_output.wav
# 192
# ['file', '192', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_183_pitch_-3_output.wav
# 183
# ['file', '183', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_109_original_output.wav
# 109
# ['file', '109', 'original', 'output.wav']
# file_167_tempo_1.5_output.wav
# 167
# ['file', '167', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_151_tempo_1.75_output.wav
# 151
# ['file', '151', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_197_pitch_1_output.wav
# 197
# ['file', '197', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_127_original_output.wav
# 127
# ['file', '127', 'original', 'output.wav']
# file_180_vol_30_output.wav
# 180
# ['file', '180', 'vol', '30', 'output.wav']
# Applying volume shift of 30 velocity.
# file_105_original_output.wav
# 105
# ['file', '105', 'original', 'output.wav']
# file_104_vol_17_output.wav
# 104
# ['file', '104', 'vol', '17', 'output.wav']
# Applying volume shift of 17 velocity.
# file_198_original_output.wav
# 198
# ['file', '198', 'original', 'output.wav']
# file_193_vol_5_output.wav
# 193
# ['file', '193', 'vol', '5', 'output.wav']
# Applying volume shift of 5 velocity.
# file_152_vol_0_output.wav
# 152
# ['file', '152', 'vol', '0', 'output.wav']
# Applying volume shift of 0 velocity.
# file_166_vol_-18_output.wav
# 166
# ['file', '166', 'vol', '-18', 'output.wav']
# Applying volume shift of -18 velocity.
# file_178_original_output.wav
# 178
# ['file', '178', 'original', 'output.wav']
# file_203_pitch_1_output.wav
# 203
# ['file', '203', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_124_vol_-29_output.wav
# 124
# ['file', '124', 'vol', '-29', 'output.wav']
# Applying volume shift of -29 velocity.
# file_149_vol_22_output.wav
# 149
# ['file', '149', 'vol', '22', 'output.wav']
# Applying volume shift of 22 velocity.
# file_156_original_output.wav
# 156
# ['file', '156', 'original', 'output.wav']
# file_181_tempo_1.75_output.wav
# 181
# ['file', '181', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_121_vol_-15_output.wav
# 121
# ['file', '121', 'vol', '-15', 'output.wav']
# Applying volume shift of -15 velocity.
# file_168_original_output.wav
# 168
# ['file', '168', 'original', 'output.wav']
# file_132_original_output.wav
# 132
# ['file', '132', 'original', 'output.wav']
# file_182_tempo_0.5_output.wav
# 182
# ['file', '182', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_158_vol_-14_output.wav
# 158
# ['file', '158', 'vol', '-14', 'output.wav']
# Applying volume shift of -14 velocity.
# file_186_vol_4_output.wav
# 186
# ['file', '186', 'vol', '4', 'output.wav']
# Applying volume shift of 4 velocity.
# file_129_tempo_0.5_output.wav
# 129
# ['file', '129', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_172_original_output.wav
# 172
# ['file', '172', 'original', 'output.wav']
# file_119_original_output.wav
# 119
# ['file', '119', 'original', 'output.wav']
# file_101_vol_20_output.wav
# 101
# ['file', '101', 'vol', '20', 'output.wav']
# Applying volume shift of 20 velocity.
# file_161_tempo_0.75_output.wav
# 161
# ['file', '161', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_176_tempo_1.75_output.wav
# 176
# ['file', '176', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_145_original_output.wav
# 145
# ['file', '145', 'original', 'output.wav']
# file_155_pitch_2_output.wav
# 155
# ['file', '155', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_122_original_output.wav
# 122
# ['file', '122', 'original', 'output.wav']
# file_144_original_output.wav
# 144
# ['file', '144', 'original', 'output.wav']
# file_186_pitch_-3_output.wav
# 186
# ['file', '186', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_122_pitch_0_output.wav
# 122
# ['file', '122', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_135_pitch_-3_output.wav
# 135
# ['file', '135', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_170_tempo_0.5_output.wav
# 170
# ['file', '170', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_120_pitch_6_output.wav
# 120
# ['file', '120', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_161_vol_-8_output.wav
# 161
# ['file', '161', 'vol', '-8', 'output.wav']
# Applying volume shift of -8 velocity.
# file_195_vol_2_output.wav
# 195
# ['file', '195', 'vol', '2', 'output.wav']
# Applying volume shift of 2 velocity.
# file_103_vol_16_output.wav
# 103
# ['file', '103', 'vol', '16', 'output.wav']
# Applying volume shift of 16 velocity.
# file_112_pitch_0_output.wav
# 112
# ['file', '112', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_104_pitch_-5_output.wav
# 104
# ['file', '104', 'pitch', '-5', 'output.wav']
# Applying pitch shift of -5 semitones.
# file_111_pitch_-6_output.wav
# 111
# ['file', '111', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_199_tempo_1.75_output.wav
# 199
# ['file', '199', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_179_vol_-2_output.wav
# 179
# ['file', '179', 'vol', '-2', 'output.wav']
# Applying volume shift of -2 velocity.
# file_169_vol_-20_output.wav
# 169
# ['file', '169', 'vol', '-20', 'output.wav']
# Applying volume shift of -20 velocity.
# file_109_pitch_3_output.wav
# 109
# ['file', '109', 'pitch', '3', 'output.wav']
# Applying pitch shift of 3 semitones.
# file_192_original_output.wav
# 192
# ['file', '192', 'original', 'output.wav']
# file_108_original_output.wav
# 108
# ['file', '108', 'original', 'output.wav']
# file_173_vol_-21_output.wav
# 173
# ['file', '173', 'vol', '-21', 'output.wav']
# Applying volume shift of -21 velocity.
# file_182_original_output.wav
# 182
# ['file', '182', 'original', 'output.wav']
# file_201_pitch_0_output.wav
# 201
# ['file', '201', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_107_tempo_0.5_output.wav
# 107
# ['file', '107', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_179_pitch_5_output.wav
# 179
# ['file', '179', 'pitch', '5', 'output.wav']
# Applying pitch shift of 5 semitones.
# file_120_original_output.wav
# 120
# ['file', '120', 'original', 'output.wav']
# file_135_vol_-16_output.wav
# 135
# ['file', '135', 'vol', '-16', 'output.wav']
# Applying volume shift of -16 velocity.
# file_131_original_output.wav
# 131
# ['file', '131', 'original', 'output.wav']
# file_163_tempo_0.25_output.wav
# 163
# ['file', '163', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_189_vol_2_output.wav
# 189
# ['file', '189', 'vol', '2', 'output.wav']
# Applying volume shift of 2 velocity.
# file_175_pitch_2_output.wav
# 175
# ['file', '175', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_183_vol_-16_output.wav
# 183
# ['file', '183', 'vol', '-16', 'output.wav']
# Applying volume shift of -16 velocity.
# file_116_tempo_0.5_output.wav
# 116
# ['file', '116', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_113_original_output.wav
# 113
# ['file', '113', 'original', 'output.wav']
# file_158_original_output.wav
# 158
# ['file', '158', 'original', 'output.wav']
# file_200_original_output.wav
# 200
# ['file', '200', 'original', 'output.wav']
# file_139_tempo_1.5_output.wav
# 139
# ['file', '139', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_202_pitch_-2_output.wav
# 202
# ['file', '202', 'pitch', '-2', 'output.wav']
# Applying pitch shift of -2 semitones.
# file_195_original_output.wav
# 195
# ['file', '195', 'original', 'output.wav']
# file_141_tempo_1.75_output.wav
# 141
# ['file', '141', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_176_pitch_6_output.wav
# 176
# ['file', '176', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_108_tempo_1.25_output.wav
# 108
# ['file', '108', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_141_pitch_-2_output.wav
# 141
# ['file', '141', 'pitch', '-2', 'output.wav']
# Applying pitch shift of -2 semitones.
# file_162_pitch_0_output.wav
# 162
# ['file', '162', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_177_tempo_0.75_output.wav
# 177
# ['file', '177', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_168_vol_16_output.wav
# 168
# ['file', '168', 'vol', '16', 'output.wav']
# Applying volume shift of 16 velocity.
# file_119_tempo_0.75_output.wav
# 119
# ['file', '119', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_127_vol_0_output.wav
# 127
# ['file', '127', 'vol', '0', 'output.wav']
# Applying volume shift of 0 velocity.
# file_132_pitch_0_output.wav
# 132
# ['file', '132', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_156_tempo_0.25_output.wav
# 156
# ['file', '156', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_163_pitch_-5_output.wav
# 163
# ['file', '163', 'pitch', '-5', 'output.wav']
# Applying pitch shift of -5 semitones.
# file_190_vol_-1_output.wav
# 190
# ['file', '190', 'vol', '-1', 'output.wav']
# Applying volume shift of -1 velocity.
# file_197_vol_-28_output.wav
# 197
# ['file', '197', 'vol', '-28', 'output.wav']
# Applying volume shift of -28 velocity.
# file_196_vol_-8_output.wav
# 196
# ['file', '196', 'vol', '-8', 'output.wav']
# Applying volume shift of -8 velocity.
# file_102_vol_24_output.wav
# 102
# ['file', '102', 'vol', '24', 'output.wav']
# Applying volume shift of 24 velocity.
# file_147_pitch_-2_output.wav
# 147
# ['file', '147', 'pitch', '-2', 'output.wav']
# Applying pitch shift of -2 semitones.
# file_115_pitch_-6_output.wav
# 115
# ['file', '115', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_150_original_output.wav
# 150
# ['file', '150', 'original', 'output.wav']
# file_204_vol_16_output.wav
# 204
# ['file', '204', 'vol', '16', 'output.wav']
# Applying volume shift of 16 velocity.
# file_174_original_output.wav
# 174
# ['file', '174', 'original', 'output.wav']
# file_185_pitch_-3_output.wav
# 185
# ['file', '185', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_201_vol_24_output.wav
# 201
# ['file', '201', 'vol', '24', 'output.wav']
# Applying volume shift of 24 velocity.
# file_118_tempo_1.25_output.wav
# 118
# ['file', '118', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_133_original_output.wav
# 133
# ['file', '133', 'original', 'output.wav']
# file_130_original_output.wav
# 130
# ['file', '130', 'original', 'output.wav']
# file_119_vol_11_output.wav
# 119
# ['file', '119', 'vol', '11', 'output.wav']
# Applying volume shift of 11 velocity.
# file_148_original_output.wav
# 148
# ['file', '148', 'original', 'output.wav']
# file_135_original_output.wav
# 135
# ['file', '135', 'original', 'output.wav']
# file_199_original_output.wav
# 199
# ['file', '199', 'original', 'output.wav']
# file_104_tempo_1.75_output.wav
# 104
# ['file', '104', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_104_original_output.wav
# 104
# ['file', '104', 'original', 'output.wav']
# file_129_vol_-18_output.wav
# 129
# ['file', '129', 'vol', '-18', 'output.wav']
# Applying volume shift of -18 velocity.
# file_148_pitch_-6_output.wav
# 148
# ['file', '148', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_113_tempo_1.5_output.wav
# 113
# ['file', '113', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_161_pitch_2_output.wav
# 161
# ['file', '161', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_156_vol_-12_output.wav
# 156
# ['file', '156', 'vol', '-12', 'output.wav']
# Applying volume shift of -12 velocity.
# file_197_original_output.wav
# 197
# ['file', '197', 'original', 'output.wav']
# file_116_original_output.wav
# 116
# ['file', '116', 'original', 'output.wav']
# file_170_pitch_-6_output.wav
# 170
# ['file', '170', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_114_pitch_6_output.wav
# 114
# ['file', '114', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_177_pitch_2_output.wav
# 177
# ['file', '177', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_190_pitch_3_output.wav
# 190
# ['file', '190', 'pitch', '3', 'output.wav']
# Applying pitch shift of 3 semitones.
# file_125_pitch_-2_output.wav
# 125
# ['file', '125', 'pitch', '-2', 'output.wav']
# Applying pitch shift of -2 semitones.
# file_124_original_output.wav
# 124
# ['file', '124', 'original', 'output.wav']
# file_119_pitch_3_output.wav
# 119
# ['file', '119', 'pitch', '3', 'output.wav']
# Applying pitch shift of 3 semitones.
# file_103_tempo_1.25_output.wav
# 103
# ['file', '103', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_203_tempo_0.5_output.wav
# 203
# ['file', '203', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_120_tempo_0.75_output.wav
# 120
# ['file', '120', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_163_original_output.wav
# 163
# ['file', '163', 'original', 'output.wav']
# file_188_original_output.wav
# 188
# ['file', '188', 'original', 'output.wav']
# file_124_pitch_1_output.wav
# 124
# ['file', '124', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_180_pitch_-1_output.wav
# 180
# ['file', '180', 'pitch', '-1', 'output.wav']
# Applying pitch shift of -1 semitones.
# file_174_tempo_0.25_output.wav
# 174
# ['file', '174', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_162_vol_10_output.wav
# 162
# ['file', '162', 'vol', '10', 'output.wav']
# Applying volume shift of 10 velocity.
# file_180_original_output.wav
# 180
# ['file', '180', 'original', 'output.wav']
# file_115_vol_-12_output.wav
# 115
# ['file', '115', 'vol', '-12', 'output.wav']
# Applying volume shift of -12 velocity.
# file_146_pitch_-5_output.wav
# 146
# ['file', '146', 'pitch', '-5', 'output.wav']
# Applying pitch shift of -5 semitones.
# file_139_vol_1_output.wav
# 139
# ['file', '139', 'vol', '1', 'output.wav']
# Applying volume shift of 1 velocity.
# file_173_tempo_1.75_output.wav
# 173
# ['file', '173', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_158_pitch_1_output.wav
# 158
# ['file', '158', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_136_pitch_-2_output.wav
# 136
# ['file', '136', 'pitch', '-2', 'output.wav']
# Applying pitch shift of -2 semitones.
# file_153_tempo_0.25_output.wav
# 153
# ['file', '153', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_193_tempo_1.25_output.wav
# 193
# ['file', '193', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_151_vol_-7_output.wav
# 151
# ['file', '151', 'vol', '-7', 'output.wav']
# Applying volume shift of -7 velocity.
# file_132_tempo_0.5_output.wav
# 132
# ['file', '132', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_129_original_output.wav
# 129
# ['file', '129', 'original', 'output.wav']
# file_142_original_output.wav
# 142
# ['file', '142', 'original', 'output.wav']
# file_144_tempo_0.75_output.wav
# 144
# ['file', '144', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_130_tempo_1.25_output.wav
# 130
# ['file', '130', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_128_original_output.wav
# 128
# ['file', '128', 'original', 'output.wav']
# file_155_original_output.wav
# 155
# ['file', '155', 'original', 'output.wav']
# file_152_pitch_-5_output.wav
# 152
# ['file', '152', 'pitch', '-5', 'output.wav']
# Applying pitch shift of -5 semitones.
# file_136_original_output.wav
# 136
# ['file', '136', 'original', 'output.wav']
# file_166_original_output.wav
# 166
# ['file', '166', 'original', 'output.wav']
# file_155_tempo_1.75_output.wav
# 155
# ['file', '155', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_155_vol_-20_output.wav
# 155
# ['file', '155', 'vol', '-20', 'output.wav']
# Applying volume shift of -20 velocity.
# file_157_pitch_5_output.wav
# 157
# ['file', '157', 'pitch', '5', 'output.wav']
# Applying pitch shift of 5 semitones.
# file_140_pitch_6_output.wav
# 140
# ['file', '140', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_187_tempo_0.25_output.wav
# 187
# ['file', '187', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_159_vol_-27_output.wav
# 159
# ['file', '159', 'vol', '-27', 'output.wav']
# Applying volume shift of -27 velocity.
# file_138_original_output.wav
# 138
# ['file', '138', 'original', 'output.wav']
# file_168_pitch_2_output.wav
# 168
# ['file', '168', 'pitch', '2', 'output.wav']
# Applying pitch shift of 2 semitones.
# file_175_tempo_1.5_output.wav
# 175
# ['file', '175', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_143_original_output.wav
# 143
# ['file', '143', 'original', 'output.wav']
# file_106_vol_-8_output.wav
# 106
# ['file', '106', 'vol', '-8', 'output.wav']
# Applying volume shift of -8 velocity.
# file_116_vol_-7_output.wav
# 116
# ['file', '116', 'vol', '-7', 'output.wav']
# Applying volume shift of -7 velocity.
# file_117_pitch_6_output.wav
# 117
# ['file', '117', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_177_original_output.wav
# 177
# ['file', '177', 'original', 'output.wav']
# file_185_vol_-20_output.wav
# 185
# ['file', '185', 'vol', '-20', 'output.wav']
# Applying volume shift of -20 velocity.
# file_206_original_output.wav
# 206
# ['file', '206', 'original', 'output.wav']
# file_133_pitch_1_output.wav
# 133
# ['file', '133', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_200_tempo_0.5_output.wav
# 200
# ['file', '200', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_123_original_output.wav
# 123
# ['file', '123', 'original', 'output.wav']
# file_202_original_output.wav
# 202
# ['file', '202', 'original', 'output.wav']
# file_140_vol_-1_output.wav
# 140
# ['file', '140', 'vol', '-1', 'output.wav']
# Applying volume shift of -1 velocity.
# file_199_pitch_-3_output.wav
# 199
# ['file', '199', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_101_tempo_0.25_output.wav
# 101
# ['file', '101', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_188_pitch_3_output.wav
# 188
# ['file', '188', 'pitch', '3', 'output.wav']
# Applying pitch shift of 3 semitones.
# file_193_pitch_-6_output.wav
# 193
# ['file', '193', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_165_original_output.wav
# 165
# ['file', '165', 'original', 'output.wav']
# file_152_tempo_0.25_output.wav
# 152
# ['file', '152', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_114_original_output.wav
# 114
# ['file', '114', 'original', 'output.wav']
# file_194_pitch_0_output.wav
# 194
# ['file', '194', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_188_tempo_0.75_output.wav
# 188
# ['file', '188', 'tempo', '0.75', 'output.wav']
# Applying tempo shift of 0.75 tempo.
# file_201_tempo_1.25_output.wav
# 201
# ['file', '201', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_132_vol_-29_output.wav
# 132
# ['file', '132', 'vol', '-29', 'output.wav']
# Applying volume shift of -29 velocity.
# file_202_vol_5_output.wav
# 202
# ['file', '202', 'vol', '5', 'output.wav']
# Applying volume shift of 5 velocity.
# file_174_pitch_-3_output.wav
# 174
# ['file', '174', 'pitch', '-3', 'output.wav']
# Applying pitch shift of -3 semitones.
# file_194_vol_2_output.wav
# 194
# ['file', '194', 'vol', '2', 'output.wav']
# Applying volume shift of 2 velocity.
# file_134_original_output.wav
# 134
# ['file', '134', 'original', 'output.wav']
# file_195_pitch_3_output.wav
# 195
# ['file', '195', 'pitch', '3', 'output.wav']
# Applying pitch shift of 3 semitones.
# file_126_vol_4_output.wav
# 126
# ['file', '126', 'vol', '4', 'output.wav']
# Applying volume shift of 4 velocity.
# file_196_original_output.wav
# 196
# ['file', '196', 'original', 'output.wav']
# file_107_pitch_-4_output.wav
# 107
# ['file', '107', 'pitch', '-4', 'output.wav']
# Applying pitch shift of -4 semitones.
# file_170_vol_23_output.wav
# 170
# ['file', '170', 'vol', '23', 'output.wav']
# Applying volume shift of 23 velocity.
# file_184_tempo_1.25_output.wav
# 184
# ['file', '184', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_154_original_output.wav
# 154
# ['file', '154', 'original', 'output.wav']
# file_100_original_output.wav
# 100
# ['file', '100', 'original', 'output.wav']
# file_154_tempo_0.25_output.wav
# 154
# ['file', '154', 'tempo', '0.25', 'output.wav']
# Applying tempo shift of 0.25 tempo.
# file_107_vol_-6_output.wav
# 107
# ['file', '107', 'vol', '-6', 'output.wav']
# Applying volume shift of -6 velocity.
# file_149_original_output.wav
# 149
# ['file', '149', 'original', 'output.wav']
# file_144_vol_2_output.wav
# 144
# ['file', '144', 'vol', '2', 'output.wav']
# Applying volume shift of 2 velocity.
# file_121_original_output.wav
# 121
# ['file', '121', 'original', 'output.wav']
# file_205_vol_-9_output.wav
# 205
# ['file', '205', 'vol', '-9', 'output.wav']
# Applying volume shift of -9 velocity.
# file_106_tempo_1.75_output.wav
# 106
# ['file', '106', 'tempo', '1.75', 'output.wav']
# Applying tempo shift of 1.75 tempo.
# file_141_original_output.wav
# 141
# ['file', '141', 'original', 'output.wav']
# file_107_original_output.wav
# 107
# ['file', '107', 'original', 'output.wav']
# file_141_vol_-14_output.wav
# 141
# ['file', '141', 'vol', '-14', 'output.wav']
# Applying volume shift of -14 velocity.
# file_173_original_output.wav
# 173
# ['file', '173', 'original', 'output.wav']
# file_115_original_output.wav
# 115
# ['file', '115', 'original', 'output.wav']
# file_100_pitch_1_output.wav
# 100
# ['file', '100', 'pitch', '1', 'output.wav']
# Applying pitch shift of 1 semitones.
# file_147_tempo_0.5_output.wav
# 147
# ['file', '147', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_178_pitch_0_output.wav
# 178
# ['file', '178', 'pitch', '0', 'output.wav']
# Applying pitch shift of 0 semitones.
# file_163_vol_-29_output.wav
# 163
# ['file', '163', 'vol', '-29', 'output.wav']
# Applying volume shift of -29 velocity.
# file_194_tempo_0.5_output.wav
# 194
# ['file', '194', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_111_original_output.wav
# 111
# ['file', '111', 'original', 'output.wav']
# file_108_vol_-13_output.wav
# 108
# ['file', '108', 'vol', '-13', 'output.wav']
# Applying volume shift of -13 velocity.
# file_157_original_output.wav
# 157
# ['file', '157', 'original', 'output.wav']
# file_122_tempo_1.5_output.wav
# 122
# ['file', '122', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_108_pitch_6_output.wav
# 108
# ['file', '108', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_184_original_output.wav
# 184
# ['file', '184', 'original', 'output.wav']
# file_175_vol_-1_output.wav
# 175
# ['file', '175', 'vol', '-1', 'output.wav']
# Applying volume shift of -1 velocity.
# file_130_vol_14_output.wav
# 130
# ['file', '130', 'vol', '14', 'output.wav']
# Applying volume shift of 14 velocity.
# file_147_vol_19_output.wav
# 147
# ['file', '147', 'vol', '19', 'output.wav']
# Applying volume shift of 19 velocity.
# file_140_tempo_1.5_output.wav
# 140
# ['file', '140', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_131_vol_17_output.wav
# 131
# ['file', '131', 'vol', '17', 'output.wav']
# Applying volume shift of 17 velocity.
# file_168_tempo_0.5_output.wav
# 168
# ['file', '168', 'tempo', '0.5', 'output.wav']
# Applying tempo shift of 0.5 tempo.
# file_167_pitch_-1_output.wav
# 167
# ['file', '167', 'pitch', '-1', 'output.wav']
# Applying pitch shift of -1 semitones.
# file_142_pitch_-6_output.wav
# 142
# ['file', '142', 'pitch', '-6', 'output.wav']
# Applying pitch shift of -6 semitones.
# file_185_tempo_1.25_output.wav
# 185
# ['file', '185', 'tempo', '1.25', 'output.wav']
# Applying tempo shift of 1.25 tempo.
# file_157_tempo_1.5_output.wav
# 157
# ['file', '157', 'tempo', '1.5', 'output.wav']
# Applying tempo shift of 1.5 tempo.
# file_192_vol_-8_output.wav
# 192
# ['file', '192', 'vol', '-8', 'output.wav']
# Applying volume shift of -8 velocity.
# file_182_pitch_-1_output.wav
# 182
# ['file', '182', 'pitch', '-1', 'output.wav']
# Applying pitch shift of -1 semitones.
# file_149_pitch_5_output.wav
# 149
# ['file', '149', 'pitch', '5', 'output.wav']
# Applying pitch shift of 5 semitones.
# file_160_pitch_-5_output.wav
# 160
# ['file', '160', 'pitch', '-5', 'output.wav']
# Applying pitch shift of -5 semitones.
# file_112_original_output.wav
# 112
# ['file', '112', 'original', 'output.wav']
# file_173_pitch_6_output.wav
# 173
# ['file', '173', 'pitch', '6', 'output.wav']
# Applying pitch shift of 6 semitones.
# file_143_vol_-9_output.wav
# 143
# ['file', '143', 'vol', '-9', 'output.wav']
# Applying volume shift of -9 velocity.
# file_200_vol_7_output.wav
# 200
# ['file', '200', 'vol', '7', 'output.wav']
# Applying volume shift of 7 velocity.

# %%
def get_num_special(filename):
    filename_parts = filename.split('_')
    match = re.search(r'_(\d+)_', filename)
    if match:
        return int(match.group(1)), filename_parts
    else:
        match = re.search(r'_(\d+)\.', filename)
        if match:
            return int(match.group(1)), filename_parts
        else:
          assert(False)
        return None

def find_corresponding_prompt(the_file):
    num, name_parts = get_number_of_file(file)
    # print(name_parts)
    if name_parts[2] == 'pitch':
        look_in = pitch_dir
    elif name_parts[2] == 'original':
        look_in = r'drive/MyDrive/413/original/content/augmented/original/'
    elif name_parts[2] == 'vol':
        look_in = vol_dir
    elif name_parts[2] == 'tempo':
        look_in = tempo_dir
    else:
        assert(False)
    for comparison_file in os.listdir(look_in):
        if get_num_special(comparison_file)[0] == num and comparison_file[-1] == 'v':
          return look_in, comparison_file
    assert(False)

# %%
import torchaudio
import torch

def compare(new, old, folder_of_old):
    waveform_old, sample_rate_old = torchaudio.load(folder_of_old + old, normalize=True)
    waveform_new, sample_rate_new = torchaudio.load('drive/MyDrive/413/generated/' + new, normalize=True)
    # print(waveform_old.shape)
    # INPUTS ARE STEREO OUTPUTS ARE MONO, SO WE:
    waveform_old = torch.mean(waveform_old, dim=0, keepdim=True)



    transform_old = transforms.MFCC(sample_rate=sample_rate_old, n_mfcc=13,
                                melkwargs={"n_fft": 400, "hop_length": 160,
                                           "n_mels": 23, "center": False},)
    transform_new = transforms.MFCC(sample_rate=sample_rate_new, n_mfcc=13,
                                melkwargs={"n_fft": 400, "hop_length": 160,
                                           "n_mels": 23, "center": False},)
    mfcc_old = transform_old(waveform_old)
    mfcc_new = transform_new(waveform_new)
    length_old = mfcc_old.shape[2]
    length_new = mfcc_new.shape[2]
    print(length_old)
    print(length_new)
    if length_old > length_new:
        mfcc_old = mfcc_old[:, :, -length_new:]
    else:
        mfcc_new = mfcc_new[:, :, -length_old:]
    euclid_distance = torch.norm(mfcc_new - mfcc_old, p=2)
    return euclid_distance


def print_well(ans):
    for guy in ['pitch', 'vol', 'tempo', 'original']:
      curr_list = ans[guy]
      average = sum(curr_list) / len(curr_list)
      max_value = max(curr_list)
      min_value = min(curr_list)
      print('With augmentation type ' + guy + ' we see minimum difference of ' + str(min_value))
      print('and max difference of ' + str(max_value))
      print('and average value ' + str(average))
      print(' ')
      print(' ')

answer = {'pitch': [], 'vol': [], 'tempo': [], 'original': []}
for i, file in enumerate(continuation_files):
    a = 100*i // len(continuation_files)
    if i % 10 == 0:
      print(f"\r{a}%", end="", flush=True)
    filename_parts = file.split('_')
    # print(filename_parts)
    match_file_folder, match_file = find_corresponding_prompt(file)
    difference = compare(file, match_file, match_file_folder)
    answer[filename_parts[2]].append(difference)

print(f"\r ", end="", flush=True)
print_well(answer)
